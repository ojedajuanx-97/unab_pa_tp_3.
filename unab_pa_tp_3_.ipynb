# %% [markdown]
# <a href="https://colab.research.google.com/github/ojedajuanx-97/unab_pa_tp_3./blob/main/unab_pa_tp_3_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#EJERCICIO 2

class Punto:
  def __init__ (self,x,y):
    self.x = x
    self.y = y

  def eje_y(self):
    return self.y

  def eje_x(self):
    return self.x

  def impresion(self):
    return f"({self.x}, {self.y})"

  def opuesto(self):
    return Punto(-self.x, -self.y)

# %%
#ejercicio 3

#EJERCICIO3

class Linea:
    def __init__(self, punto_a, punto_b):
        self._punto_a = punto_a
        self._punto_b = punto_b

    def mueve_derecha(self, distancia):
        self._punto_a.x += distancia
        self._punto_b.x += distancia

    def mueve_izquierda(self, distancia):
        self._punto_a.x -= distancia
        self._punto_b.x -= distancia

    def mueve_arriba(self, distancia):
        self._punto_a.y += distancia
        self._punto_b.y += distancia

    def mueve_abajo(self, distancia):
        self._punto_a.y -= distancia
        self._punto_b.y -= distancia

    def mostrar_posicion(self):
        print(f"Punto A: ({self._punto_a.x}, {self._punto_a.y})")
        print(f"Punto B: ({self._punto_b.x}, {self._punto_b.y})")

# %%
# EJERCICIO 4

class Cancion:
    def __init__(self, titulo, autor):
        self._titulo = titulo
        self._autor = autor

    def get_titulo(self):
        return self._titulo

    def get_autor(self):
        return self._autor

    def set_titulo(self, nuevo_titulo):
        self._titulo = nuevo_titulo

    def set_autor(self, nuevo_autor):
        self._autor = nuevo_autor
